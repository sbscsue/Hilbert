# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
inData = pd.read_csv("sn_convTwo.csv",header=None)

# %%
inData
# Out:
#                 0
# 0        8.896500
# 1        9.416785
# 2       10.006232
# 3       10.665221
# 4       11.389116
# ...           ...
# 649994  25.415243
# 649995  20.674912
# 649996  15.813706
# 649997  10.770847
# 649998   5.505606
#
# [649999 rows x 1 columns]

# %%
outData = pd.read_csv("out.txt",header=None)

# %%
outData
# Out:
#                  0
# 0       274.455631
# 1       144.562165
# 2       145.447930
# 3       102.494312
# 4       103.148846
# ...            ...
# 647995 -217.981635
# 647996 -224.209715
# 647997 -288.954558
# 647998 -297.336472
# 647999 -481.335969
#
# [648000 rows x 1 columns]

# %%
plt.rcParams["figure.figsize"] = (20,11)
plt.rcParams["font.size"] = 16
#plt.rcParams.update({"text.usetex": True,"font.family": "sans-serif","font.sans-serif": ["Helvetica"]})

# %%
cnt = 0
S = 10 * 1

# %%
xAxis = [360*cnt,360*(cnt+S)]
print(xAxis)
plt.plot(inData)
plt.plot(outData)
plt.xlim(xAxis)
cnt += S
# Out:
# [39600, 43200]
